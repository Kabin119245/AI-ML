# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
def load_dataset(file_path):
  return pd.read_csv(file_path)


df = load_dataset("/content/drive/MyDrive/alcohol_final.csv")
df.head(5)
# Out:
#    Unnamed: 0 Unnamed: 1 Series_reference   Period  Data_value STATUS   UNITS  \
# 0        1935        Dec          ALCA.S1  1935.12        51.1  FINAL  Litres
# 1        1936        Dec          ALCA.S1  1936.12        58.7  FINAL  Litres
# 2        1937        Dec          ALCA.S1  1937.12        68.7  FINAL  Litres
# 3        1938        Dec          ALCA.S1  1938.12        78.1  FINAL  Litres
# 4        1939        Dec          ALCA.S1  1939.12        79.2  FINAL  Litres
#
#    MAGNTUDE                                  Subject  \
# 0         6  Alcohol Available for Consumption - ALC
# 1         6  Alcohol Available for Consumption - ALC
# 2         6  Alcohol Available for Consumption - ALC
# 3         6  Alcohol Available for Consumption - ALC
# 4         6  Alcohol Available for Consumption - ALC
#
#                              Group Series_title_1  Series_title_2  \
# 0  (DISC) Volume & Volume Per Head           Beer             NaN
# ...

# %%
sns.countplot(data=df)
df['Series_title_1'].value_counts()
# Out:
# Beer                47
# Wine                47
# Spirits             47
# Beer Per Head       47
# Wine Per Head       47
# Spirits Per Head    46
# Name: Series_title_1, dtype: int64

# %%
df['Series_title_1'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='Series_title_1'>

# %%
plt.hist(df['Data_value'])
# Out:
# (array([192.,  14.,  24.,  14.,   5.,   6.,   5.,   4.,   3.,   9.]),
#  array([  0.  ,  39.87,  79.74, 119.61, 159.48, 199.35, 239.22, 279.09,
#         318.96, 358.83, 398.7 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Data_value'])
# Out:
# <ipython-input-11-ad8702fc5147>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Data_value'])
# <Axes: xlabel='Data_value', ylabel='Density'>

# %%
sns.boxplot(df['Data_value'])
# Out:
# <Axes: >

# %%
sns.barplot(x='Series_title_1',y='Data_value',hue='Unnamed: 1',data=df)
# Out:
# <Axes: xlabel='Series_title_1', ylabel='Data_value'>

# %%
sns.heatmap(pd.crosstab(df['Data_value'],df['Series_title_1']))
# Out:
# <Axes: xlabel='Series_title_1', ylabel='Data_value'>
